# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.linspace(50,150,300)
y = np.linspace(50,150,300)
X,Y = np.meshgrid(x,y)
plt.scatter(X,Y,c=Y)
