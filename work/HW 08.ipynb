# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from IPython.display import YouTubeVideo

# %%
v = [0,1,2,3,4]
v[0] = YouTubeVideo("2Vv-BfVoq4g")
v[1] = YouTubeVideo("JGwWNGJdvx8")
v[2] = YouTubeVideo("y83x7MgzWOA")
v[3] = YouTubeVideo("mj0XInqZMHY")
v[4] = YouTubeVideo("Wv2rLZmbPMA")

# %%
print("0:Perfect")
print("1:Shape of You")
print("2:I Don't Care(wif. Justin Bieber)")
print("3:Beautiful People (feat. Khalid)")
print("4:Dive")
s = int(input("How much songs do u want? : "))
for i in range(s):
    i = int(input("Enter code of song u want:"))
    display(v[i])
# Out:
# 0:Perfect
# 1:Shape of You
# 2:I Don't Care(wif. Justin Bieber)
# 3:Beautiful People (feat. Khalid)
# 4:Dive
# How much songs do u want? : 3
# Enter code of song u want:1
# Enter code of song u want:4
# Enter code of song u want:0
