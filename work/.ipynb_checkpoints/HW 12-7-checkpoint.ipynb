# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=np.linspace(0,20,40)
y=np.linspace(0,20,40)
X,Y=np.meshgrid(x,y)
Z=np.random.randint(0,2,1600)
Z=Z.reshape(X.shape)
plt.contourf(X,Y,Z,cmap="magma")
