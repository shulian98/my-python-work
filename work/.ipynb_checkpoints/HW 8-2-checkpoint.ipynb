# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_tmp = pd.read_html('https://tw.stock.yahoo.com/s/list.php?c=%A8T%A8%AE&rr=0.51853600%201573389823',encoding='big5')

# %%
len(df_tmp)
# Out:
# 5

# %%
for i,table in enumerate(df_tmp):
    print(i,len(table))
# Out:
# 0 1
# 1 1
# 2 31
# 3 1
# 4 1

# %%
df_tmp[2].head()
# Out:
#    選擇        股票代號     時間     成交     買進     賣出     漲跌   張數     昨收     開盤  \
# 0 NaN     1319 東陽  14:30  46.90  46.85  46.90  ▽0.15  825  47.05  47.05
# 1 NaN  1338 廣華-KY  13:30  62.80  62.60  62.90   △0.3   85  62.50  62.50
# 2 NaN     1339 昭輝  14:30  46.15  46.10  46.20  △1.20  462  44.95  45.50
# 3 NaN     1512 瑞利  13:24   5.29   5.20   5.29  △0.09   57   5.20   5.19
# 4 NaN     1521 大億  13:30  64.70  64.70  65.00   ▽0.2   46  64.90  64.90
#
#       最高     最低
# 0  47.40  46.50
# 1  62.90  62.40
# 2  46.40  45.40
# 3   5.29   5.19
# 4  65.00  64.70

# %%
df=df_tmp[2]

# %%
df.head()
# Out:
#    選擇        股票代號     時間     成交     買進     賣出     漲跌   張數     昨收     開盤  \
# 0 NaN     1319 東陽  14:30  46.90  46.85  46.90  ▽0.15  825  47.05  47.05
# 1 NaN  1338 廣華-KY  13:30  62.80  62.60  62.90   △0.3   85  62.50  62.50
# 2 NaN     1339 昭輝  14:30  46.15  46.10  46.20  △1.20  462  44.95  45.50
# 3 NaN     1512 瑞利  13:24   5.29   5.20   5.29  △0.09   57   5.20   5.19
# 4 NaN     1521 大億  13:30  64.70  64.70  65.00   ▽0.2   46  64.90  64.90
#
#       最高     最低
# 0  47.40  46.50
# 1  62.90  62.40
# 2  46.40  45.40
# 3   5.29   5.19
# 4  65.00  64.70

# %%
df.drop('選擇',axis=1,inplace=True)

# %%
df.head()
# Out:
#          股票代號     時間     成交     買進     賣出     漲跌   張數     昨收     開盤     最高  \
# 0     1319 東陽  14:30  46.90  46.85  46.90  ▽0.15  825  47.05  47.05  47.40
# 1  1338 廣華-KY  13:30  62.80  62.60  62.90   △0.3   85  62.50  62.50  62.90
# 2     1339 昭輝  14:30  46.15  46.10  46.20  △1.20  462  44.95  45.50  46.40
# 3     1512 瑞利  13:24   5.29   5.20   5.29  △0.09   57   5.20   5.19   5.29
# 4     1521 大億  13:30  64.70  64.70  65.00   ▽0.2   46  64.90  64.90  65.00
#
#       最低
# 0  46.50
# 1  62.40
# 2  45.40
# 3   5.19
# 4  64.70

# %%
df_sorted = df.sort_values(by="漲跌")

# %%
df_sorted
# Out:
#           股票代號     時間      成交      買進      賣出     漲跌    張數      昨收      開盤  \
# 30     6605 帝寶  13:30   61.50   61.50   61.70   0.00    92   61.50   61.50
# 11     1587 吉茂  13:30   16.60   16.50   16.60   0.00    25   16.60   16.55
# 24  2243 宏旭-KY  13:04   13.40   13.35   13.40  △0.05     8   13.35   13.70
# 8     1533 車王電  13:30   36.80   36.80   36.95  △0.05    54   36.75   36.80
# 3      1512 瑞利  13:24    5.29    5.20    5.29  △0.09    57    5.20    5.19
# 16   2206 三陽工業  13:30   22.15   22.10   22.15  △0.10   764   22.05   22.05
# 13  2115 六暉-KY  11:59   39.05   39.00   39.05  △0.10    26   38.95   39.40
# 15     2204 中華  13:30   41.00   40.95   41.05  △0.15   250   40.85   41.05
# 28  4557 永新-KY  13:15   68.70   68.60   68.80   △0.2    16   68.50   68.50
# 1   1338 廣華-KY  13:30   62.80   62.60   62.90   △0.3    85   62.50   62.50
# 5     1522 堤維西  14:30   29.80   29.80   29.85  △0.45  1504   29.35   29.30
# ...

# %%
df_sorted["張數"].mean()
# Out:
# 533.741935483871

# %%
df_sorted["張數"].std()
# Out:
# 992.6548231129804
