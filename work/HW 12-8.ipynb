# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.random.randn(300,3)
y = np.random.randint(0,20,300)
plt.scatter(x[:,0],x[:,1],c=y,s=100,alpha=0.9,cmap="Set3")
