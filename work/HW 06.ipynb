# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/chipotle.tsv",delimiter="\t")

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df2 = df.groupby("item_name").count()

# %%
df2.head(5)
# Out:
#                        order_id  quantity  choice_description  item_price
# item_name
# 6 Pack Soft Drink            54        54                  54          54
# Barbacoa Bowl                66        66                  66          66
# Barbacoa Burrito             91        91                  91          91
# Barbacoa Crispy Tacos        11        11                  11          11
# Barbacoa Salad Bowl          10        10                  10          10

# %%
df2.quantity.plot(kind="bar")
