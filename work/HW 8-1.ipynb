# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data')

# %%
df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
df.tail()
# Out:
#      vhigh vhigh.1      2   2.1 small   low  unacc
# 1722   low     low  5more  more   med   med   good
# 1723   low     low  5more  more   med  high  vgood
# 1724   low     low  5more  more   big   low  unacc
# 1725   low     low  5more  more   big   med   good
# 1726   low     low  5more  more   big  high  vgood

# %%
column_names="buying,maint,doors,persons,lug_boot,safety,class_values".split(',')

# %%
len(column_names)
# Out:
# 7

# %%
df=pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data',names=column_names)

# %%
df.head()
# Out:
#   buying  maint doors persons lug_boot safety class_values
# 0  vhigh  vhigh     2       2    small    low        unacc
# 1  vhigh  vhigh     2       2    small    med        unacc
# 2  vhigh  vhigh     2       2    small   high        unacc
# 3  vhigh  vhigh     2       2      med    low        unacc
# 4  vhigh  vhigh     2       2      med    med        unacc

# %%
df_sorted = df.sort_values(by="class_values")

# %%
df_sorted
# Out:
#      buying  maint  doors persons lug_boot safety class_values
# 863    high    low  5more    more      big   high          acc
# 565    high   high      2    more      big    med          acc
# 566    high   high      2    more      big   high          acc
# 1186    med    med  5more    more      big    med          acc
# 1183    med    med  5more    more      med    med          acc
# 1181    med    med  5more    more    small   high          acc
# 1180    med    med  5more    more    small    med          acc
# 1177    med    med  5more       4      big    med          acc
# 1174    med    med  5more       4      med    med          acc
# 578    high   high      3       4    small   high          acc
# 1172    med    med  5more       4    small   high          acc
# 1171    med    med  5more       4    small    med          acc
# 581    high   high      3       4      med   high          acc
# 583    high   high      3       4      big    med          acc
# ...

# %%
df_sorted.index=range(1,1729)

# %%
df_sorted
# Out:
#      buying  maint  doors persons lug_boot safety class_values
# 1      high    low  5more    more      big   high          acc
# 2      high   high      2    more      big    med          acc
# 3      high   high      2    more      big   high          acc
# 4       med    med  5more    more      big    med          acc
# 5       med    med  5more    more      med    med          acc
# 6       med    med  5more    more    small   high          acc
# 7       med    med  5more    more    small    med          acc
# 8       med    med  5more       4      big    med          acc
# 9       med    med  5more       4      med    med          acc
# 10     high   high      3       4    small   high          acc
# 11      med    med  5more       4    small   high          acc
# 12      med    med  5more       4    small    med          acc
# 13     high   high      3       4      med   high          acc
# 14     high   high      3       4      big    med          acc
# ...
